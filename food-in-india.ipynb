# %% [markdown]
# # <span style="color:Blue;">**RESTURANTS IN INDIA**

# %% [markdown]
# #  **<span style="color:green;">Introduction**
#
# I want to open a restaurant in india and i want to check what is neccecery to Open a restaurant in India is an exciting venture that promises a rich and diverse culinary experience. India, known for its vibrant food culture, offers a myriad of flavors, spices, and regional specialties that can captivate the taste buds of food enthusiasts. From the savory delights of North Indian cuisine to the fiery curries of the South, the culinary landscape is as diverse as the country itself. Establishing a restaurant in India involves embracing this diversity and creating a menu that reflects the unique tastes of the region. Additionally, understanding the importance of hospitality and warmth in Indian culture is crucial for building a loyal customer base. With a booming population of food enthusiasts, a well-thought-out concept, and a commitment to delivering exceptional dining experiences, opening a restaurant in India can be a fulfilling and rewarding journey in the world of gastronomy.

# %% [markdown]
# # **<span style="color:lightgreen;">Main idea**
#
# In this project, I am going to embark on an insightful exploration of restaurant ratings in India by analyzing the impact of two key parameters: the booking table process and the price range of meals. By delving into the rates assigned to restaurants based on their reservation practices and the cost of their offerings, you aim to unravel the correlation between these factors and the overall rating of the establishments. This approach provides a comprehensive perspective on the dining experience, considering both the convenience of booking tables and the overall rate.

# %% [markdown]
#  # <span style="color:lightblue;">Exploring the data</span>

# %%
# import the relevent libaries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %% [markdown]
# #  **<span style="color: Gold;">Presention of the data(in a table)**

# %%
#load the csv file 
url= ('/kaggle/input/zomato-bangalore-restaurants/zomato.csv')
india = pd.read_csv(url)
india.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# <span style="color:Blue;">Presention of the info of the data</span>

# %%
india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %% [markdown]
#  <span style="color:green;">Peresnting the dataframe</span>

# %%
df = pd.DataFrame(india)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# <span style="color:orange;">Showing the dataframe after removing missing values</span>

# %%
dropdf = india.dropna()
dropdf = dropdf.drop(index=10)
dropdf
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# <span style="color:brown;">Summing the missing values after the drop</span>

# %%
dropdf.isna().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %% [markdown]
# <span style="color:gray;">Data frame peresntion as a list</span>

# %%
dropdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23192 entries, 0 to 51715
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23192 non-null  object
#  1   address                      23192 non-null  object
#  2   name                         23192 non-null  object
#  3   online_order                 23192 non-null  object
#  4   book_table                   23192 non-null  object
#  5   rate                         23192 non-null  object
#  6   votes                        23192 non-null  int64
#  7   phone                        23192 non-null  object
#  8   location                     23192 non-null  object
#  9   rest_type                    23192 non-null  object
#  10  dish_liked                   23192 non-null  object
#  11  cuisines                     23192 non-null  object
#  12  approx_cost(for two people)  23192 non-null  object
# ...

# %% [markdown]
# <span style="color:Green;">**The new dataframe (in a table)**

# %%
df = pd.DataFrame(dropdf)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# **<span style="color:Turquoise;">Summing the missing values in the main dataframe**

# %%
india.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# **<span style="color:Maroon;">Showing if there are any  duplicates**

# %%
india.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %% [markdown]
# <span style="color:Navy;">Main data shape</span>

# %%
india.shape
# Out:
# (51717, 17)

# %% [markdown]
# **<span style="color:teal;">New data shape</span>**

# %%
dropdf.shape
# Out:
# (23192, 17)

# %% [markdown]
# **<span style="color:Teal;">Important columns that i used for my research</span>**

# %%
india
india['rate'].describe()
# Out:
# count     43942
# unique       64
# top         NEW
# freq       2208
# Name: rate, dtype: object

# %% [markdown]
# **<span style="color:Olive;">The rate column is import, beacuse i want to show the corralation between the rate and the way of ordering a table in a resturant effect each other</span>**

# %%
india['online_order'].describe()
# Out:
# count     51717
# unique        2
# top         Yes
# freq      30444
# Name: online_order, dtype: object

# %%
india['online_order'].value_counts().plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Online Order Distribution in India')
plt.xlabel('Online Order')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <span style="color:Maroon;">The online_order column is import, beacuse i want to show the effection of it on the rate given by the customers after there online order of a table</span>

# %% [markdown]
# <span style="color:Navy;">Showing the new column called : delivery in the dataframe</span>

# %%
india.loc[:, 'delivery'] = india['online_order'].apply(lambda x: 'Delivery' if x == 'Yes' else 'No Delivery')
india
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# <span style="color:Olive;">Presnting the type on the column called : delivey</span>

# %%
print(india['delivery'].dtype)
# Out:
# object

# %% [markdown]
# <span style="color:SteelBlue;">The unique values of the new column</span>

# %%
print(india['delivery'].unique())
# Out:
# ['Delivery' 'No Delivery']

# %% [markdown]
# <span style="color:DeepSkyBlue;">Converting a non numeric column into a numeric one</span>

# %%
india['delivery'] = india['delivery'].astype(str)
india['delivery'] = india['delivery'].str.strip()
india.loc[:, 'delivery'] = india['delivery'].replace({'Delivery': 1, 'No Delivery': 0})
pd.set_option('future.no_silent_downcasting', True)
# Out:
# /tmp/ipykernel_19/2533528101.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   india.loc[:, 'delivery'] = india['delivery'].replace({'Delivery': 1, 'No Delivery': 0})

# %% [markdown]
# <span style="color:SlateBlue;">The new coluom in a numeric form</span>

# %%
india['delivery']
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 51712    0
# 51713    0
# 51714    0
# 51715    0
# 51716    0
# Name: delivery, Length: 51717, dtype: object

# %% [markdown]
# <span style="color:GoldenRod;">Statistical description of the 'online_order' variable in the dataset, providing insights into its central tendency, dispersion, and other key statistical parameters.</span>

# %%
india['book_table'].describe()
# Out:
# count     51717
# unique        2
# top          No
# freq      45268
# Name: book_table, dtype: object

# %% [markdown]
# <span style="color:DarkTurquoise;">Statistical description of the 'book_table' variable in the dataset, providing insights into its central tendency, dispersion, and other key statistical parameters.</span>

# %%
sns.countplot(data=india, x='book_table', palette='Set2')
plt.title('Distribution of Table Booking Availability in India')
plt.xlabel('Book Table')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <span style="color:Chocolate;">The book_table column is import, beacuse i want to show the effection of it on the rate given by the customers after they called the resturant to order a table.</span>

# %% [markdown]
# <span style="color:Navy;">Presnting the types of the variables</span>

# %%
india.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# delivery                       object
# dtype: object

# %% [markdown]
# <span style="color:green;">Presenting the correlation between online_order and book_table via graph</span>

# %%
sns.countplot(x='online_order', hue='book_table', data=india, palette='Paired')


plt.xlabel('Online Order')
plt.ylabel('Count')
plt.title('Online Order vs Book Table')


plt.show()

# %% [markdown]
# <span style="color:Teal;">Showing the statistic of votes</span>

# %%
india['votes'].describe()
# Out:
# count    51717.000000
# mean       283.697527
# std        803.838853
# min          0.000000
# 25%          7.000000
# 50%         41.000000
# 75%        198.000000
# max      16832.000000
# Name: votes, dtype: float64

# %% [markdown]
# <span style="color:green;">showing the quantile of votes (the 25%, the median and the 75%)</span>

# %%
twenty_fifth = india["votes"].quantile(0.25)


votes_median = india["votes"].median()


seventy_fifth = india["votes"].quantile(0.75)
print(twenty_fifth, votes_median, seventy_fifth)
# Out:
# 7.0 41.0 198.0

# %% [markdown]
# <span style="color:Sienna;">The distribution of statistics in the graph</span>

# %%
votes_column = india['votes']


sns.boxplot(x=votes_column)
plt.title('Votes Statistics')
plt.xlabel('Votes')
plt.show()

# %% [markdown]
# <span style="color:Navy;">Analyzing the Popular Vote: Restaurant Distribution Amongst Those with 30+ Votes</span>

# %%
india_filtered = india[india['votes'] > 30]


sns.set(style='whitegrid')


plt.figure(figsize=(10, 6))
sns.histplot(india_filtered['votes'], bins=20, kde=True, color='skyblue')

plt.xlabel('Number of Votes')
plt.ylabel('Frequency')
plt.title('Distribution of Votes for Restaurants with more than 30 Votes')


plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <span style="color:MediumSeaGreen;">A Fancution that changed the rate column into a numeric column</span>

# %%
def handlerate(value):
    if(value=='NEW' or value=='-'):
        return np.nan
    else:
        value = str(value).split('/')
        value = value[0]
        return float(value)
india['rate'] = india['rate'].apply(handlerate)
india['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %% [markdown]
# <span style="color:SlateBlue;">Presnting the new numeric rate column</span>

# %%
india['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %% [markdown]
# <span style="color:DarkTurquoise;">Showing the colums i kept for my research</span>

# %%
india[["url","online_order", "book_table", "rate", "votes"]]
# Out:
#                                                      url online_order  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...          Yes
# 1      https://www.zomato.com/bangalore/spice-elephan...          Yes
# 2      https://www.zomato.com/SanchurroBangalore?cont...          Yes
# 3      https://www.zomato.com/bangalore/addhuri-udupi...           No
# 4      https://www.zomato.com/bangalore/grand-village...           No
# ...                                                  ...          ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...           No
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...           No
# 51714  https://www.zomato.com/bangalore/plunge-sherat...           No
# 51715  https://www.zomato.com/bangalore/chime-sherato...           No
# 51716  https://www.zomato.com/bangalore/the-nest-the-...           No
#
#       book_table  rate  votes
# 0            Yes   4.1    775
# 1             No   4.1    787
# 2             No   3.8    918
# ...

# %% [markdown]
# <span style="color:DarkSalmon;">The graph illustrates the distribution of rates, showcasing the variability and pattern of values across the dataset.</span>

# %%
data = india['rate']
sns.histplot(data, bins=20, kde=False, color='skyblue')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of rate')


plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <span style="color:Teal;">Downsample the resturants that have less the 30 votes</span>

# %%
under_30_votes = india[india['votes'] < 30]


remove_percentage = int(0.2 * len(under_30_votes))


remove_indices = under_30_votes.sample(n=remove_percentage).index
india.drop(remove_indices, inplace=True)


india
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# <span style="color:Maroon;">Removing the missing values after converting the column into a numeric column</span>

# %%
india = india.dropna(subset=['rate'])
india['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 39060, dtype: float64

# %% [markdown]
# <span style="color:Chocolate;">The rate column in his numric form</span>

# %%
india.rate
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 39060, dtype: float64

# %% [markdown]
# <span style="color:orange;">The unique values of the rate column</span>

# %%
unique_values = df['rate'].unique()

# To print the unique values
print(unique_values)
# Out:
# ['4.1/5' '3.8/5' '3.7/5' '4.6/5' '4.0/5' '4.2/5' '3.9/5' '3.0/5' '3.6/5'
#  '2.8/5' '4.4/5' '3.1/5' '4.3/5' '2.6/5' '3.3/5' '3.5/5' '3.8 /5' '3.2/5'
#  '4.5/5' '2.5/5' '2.9/5' '3.4/5' '2.7/5' '4.7/5' 'NEW' '2.4/5' '2.2/5'
#  '2.3/5' '4.8/5' '3.9 /5' '4.2 /5' '4.0 /5' '4.1 /5' '2.9 /5' '2.7 /5'
#  '2.5 /5' '2.6 /5' '4.5 /5' '4.3 /5' '3.7 /5' '4.4 /5' '4.9/5' '2.1/5'
#  '2.0/5' '1.8/5' '3.4 /5' '3.6 /5' '3.3 /5' '4.6 /5' '4.9 /5' '3.2 /5'
#  '3.0 /5' '2.8 /5' '3.5 /5' '3.1 /5' '4.8 /5' '2.3 /5' '4.7 /5' '2.4 /5'
#  '2.1 /5' '2.2 /5' '2.0 /5' '1.8 /5']

# %% [markdown]
# <span style="color:Olive;">The unique numeirc values of the rate column</span>

# %%
df["clean_rate"]=df["rate"].str.replace("/5","")

unique_values = df['clean_rate'].unique()

# To print the unique values
print(unique_values)
# Out:
# ['4.1' '3.8' '3.7' '4.6' '4.0' '4.2' '3.9' '3.0' '3.6' '2.8' '4.4' '3.1'
#  '4.3' '2.6' '3.3' '3.5' '3.8 ' '3.2' '4.5' '2.5' '2.9' '3.4' '2.7' '4.7'
#  'NEW' '2.4' '2.2' '2.3' '4.8' '3.9 ' '4.2 ' '4.0 ' '4.1 ' '2.9 ' '2.7 '
#  '2.5 ' '2.6 ' '4.5 ' '4.3 ' '3.7 ' '4.4 ' '4.9' '2.1' '2.0' '1.8' '3.4 '
#  '3.6 ' '3.3 ' '4.6 ' '4.9 ' '3.2 ' '3.0 ' '2.8 ' '3.5 ' '3.1 ' '4.8 '
#  '2.3 ' '4.7 ' '2.4 ' '2.1 ' '2.2 ' '2.0 ' '1.8 ']

# %% [markdown]
# <span style="color:SteelBlue;">The new indo of the the dataframe after the changes i did</span>

# %%
india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39060 entries, 0 to 51716
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          39060 non-null  object
#  1   address                      39060 non-null  object
#  2   name                         39060 non-null  object
#  3   online_order                 39060 non-null  object
#  4   book_table                   39060 non-null  object
#  5   rate                         39060 non-null  float64
#  6   votes                        39060 non-null  int64
#  7   phone                        38311 non-null  object
#  8   location                     39060 non-null  object
#  9   rest_type                    38924 non-null  object
#  10  dish_liked                   23450 non-null  object
#  11  cuisines                     39051 non-null  object
#  12  approx_cost(for two people)  38828 non-null  object
# ...

# %% [markdown]
# <span style="color:Green;">Presenting the correlation between all the columns i used via a heatmap</span>

# %%
selected_columns = ['rate', 'votes', 'online_order', 'book_table', 'delivery']
correlation_data = india[selected_columns].copy()

# Convert 'online_order' and 'book_table' to numeric values
correlation_data['online_order'] = correlation_data['online_order'].map({'Yes': 1, 'No': 0})
correlation_data['book_table'] = correlation_data['book_table'].map({'Yes': 1, 'No': 0})

correlation_matrix = correlation_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='GnBu', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # <span style="color:Blue;"> In conclusion,</span>
# When you reserve a table online or at a restaurant, it doesn't really affect how people rate the place. The atmosphere, service, and overall experience matter more for the restaurant's rating. But when it comes to ordering food online, there's a strong connection to how we use the internet in general. Online food platforms are popular because they're convenient, fast, and offer a lot of choices, and this is a big part of how we use the internet nowadays. The easy-to-use digital menus, order tracking, and customer reviews all contribute to why we connect online food ordering with our overall experience of using internet services.
